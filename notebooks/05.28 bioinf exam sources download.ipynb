# %%
import sys
sys.path.append("../../")
from radarange_orchestrator import llm

# %%
from radarange_orchestrator.tools import all_tools
m = llm()
chat = m.chat(tools = all_tools)
# Out:
# llama_context: n_ctx_per_seq (80000) < n_ctx_train (131072) -- the full capacity of the model will not be utilized

# %%
prompt = """
Вот список ресурсов, нужных для подготовки к экзамену (нумерация сбита). За исключением материалов "Лекция", найди все остальные материалы, и дай на них ссылки (например, курс на coursera), или скачай (если статья).

1) Лекция: Геномика. NGS секвенирование
2) Курс на Coursera “Введение в биоинформатику (Introduction to Bioinformatics)” (Неделя 1 – Введение, Неделя 2 – Технологии секвенирования)
3) A decade’s perspective on DNA sequencing technology. Elaine R. Mardis. Nature volume 470, pages 198–203. doi: 10.1038/nature09796

1) Лекция: Геномика. NGS секвенирование
2) Курс на Coursera “Введение в биоинформатику (Introduction to Bioinformatics)” (Неделя 2 – Технологии секвенирования)
3) Next-Generation DNA Sequencing Methods. Elaine R. Mardis. Annu. Rev. Genomics Hum. Genet. 2008. 9:387–402. doi: 10.1146/annurev.genom.9.081307.164359
4) Genome sequencing in microfabricated high-density picolitre reactors. Marcel Margulies et al. doi: 10.1038/nature03959

1) Лекция: Контроль качества данных. Сборка геномов de novo
2) Курс на Coursera “Введение в биоинформатику (Introduction to Bioinformatics)” (Неделя 3 – Контроль качества)
3) FastQC manual: https://dnacore.missouri.edu/PDF/FastQC_Manual.pdf

1) Лекция: Контроль качества данных. Сборка геномов de novo
2) Курс на Coursera “Введение в биоинформатику (Introduction to Bioinformatics)” (Неделя 4 – Сборка ДНК de novo)
3) Genome Reconstruction: A Puzzle with a Billion Pieces. Phillip E. C. Compeau and Pavel A. Pevzner. December 22, 2010.

1) Лекция: Методы выравнивания биологических последовательностей
2) Курс на Stepike “Введение в NGS (Модуль 4– Выравнивание, базовые статистики и визуализация геномных данных)
3) https://www.ncbi.nlm.nih.gov/books/NBK20261/

1) Лекция: Методы выравнивания биологических последовательностей
2) Курс на Stepike “Введение в NGS (Модуль 4– Выравнивание, базовые статистики и визуализация геномных данных)
3) https://www.ncbi.nlm.nih.gov/books/NBK20261/

1) Лекция: Выравнивание коротких фрагментов на геном. Поиск геномных вариаций
2) Курс на Coursera “Введение в биоинформатику (Introduction to Bioinformatics)” (Неделя 5 - Выравнивание коротких фрагментов (Short read alignment))
3) https://biomolecula.ru/articles/genom-cheloveka-kak-eto-bylo-i-kak-eto-budet

Материалы для ответа на этот вопрос:
1) Лекция: Выравнивание коротких фрагментов на геном. Поиск геномных вариаций
2) Лекция “Продвинутый анализ вариаций (SNV, InDel, SV) с помощью геномного браузера NGB | Геннадий Захаров” https://www.youtube.com/watch?v=1tnsRPL3BGk

journals.plos.org/plosgenetics/article?id=10.1371/journal.pgen.1005640)

1) Лекция: Гистоновый код и открытый хроматин
2) Википедия
3) Minor Loops in Major Folds: Enhancer–Promoter Looping, Chromatin Restructuring, and Their Association with Transcriptional Regulation and Disease (http://journals.plos.org/plosgenetics/article?id=10.1371/journal.pgen.1005640)

1) Лекция: Пространственная структура хроматина
2) Википедия
3) Analysis methods for studying the 3D architecture of the genome (https://genomebiology.biomedcentral.com/articles/10.1186/s13059-015-0745-7)

1) Лекция: Пространственная структура хроматина
2) Википедия
3) Analysis methods for studying the 3D architecture of the genome (https://genomebiology.biomedcentral.com/articles/10.1186/s13059-015-0745-7)

1) Лекция: Идентификация белков и пептидов по данным масс-спектрометрии
2) Introduction to Proteomics: https://proteomesoftware.zendesk.com/hc/en-us/articles/115002058583-Introduction-to-Proteomics

1) Лекция: Идентификация белков и пептидов по данным масс-спектрометрии
2) Interpreting MS/MS Proteomics Results by Brian Searle: http://www-bac.esi.umontreal.ca/~dbcm2003/proteomique/docs/Interpreting_MSMS_results_cartoon.ppt
3) Validating Sequence Assignments: http://archive.sigda.org/cadathlon2012/p6-bio-paper.pdf

1) Лекция: Валидация результатов идентификации и оценка ошибки
2) X!Tandem Explained by Brian Searle: https://proteomesoftware.zendesk.com/hc/en-us/articles/115001448263-X-Tandem-Explained
3) Validating Sequence Assignments: http://archive.sigda.org/cadathlon2012/p6-bio-paper.pdf

1) Лекция: Валидация результатов идентификации и оценка ошибки
2) X!Tandem Explained by Brian Searle: https://proteomesoftware.zendesk.com/hc/en-us/articles/115001448263-X-Tandem-Explained
3) Validating Sequence Assignments: http://archive.sigda.org/cadathlon2012/p6-bio-paper.pdf

"""

# %%
chat.add_user_message(prompt)
m.act(chat, max_tokens_per_message = 50000, temperature=0.7, on_message=chat.append, max_prediction_rounds=100)
chat.show_final_answer()
# Out:
# Called web_search with query: Coursera Введение в биоинформатику and scrape_pages: True
# Taken 17.3 seconds to complete.
# Called download_file with href: https://doi.org/10.1038/nature09796 and filename: Mardis_2011_Nature.pdf
# Taken 17.6 seconds to complete.
# Tool evaluation led to error: Download failed: HTTPSConnectionPool(host='doi.org', port=443): Max retries exceeded with url: /10.1 ...  connection: [Errno 101] Network is unreachable'))
# Called download_file with href: https://doi.org/10.1146/annurev-genom.9.081307.164359 and filename: Mardis_2008_AnnRev.pdf
# Taken 0.4 seconds to complete.
# Tool evaluation led to error: Download failed: 404 Client Error: Not Found for url: https://doi.org/10.1146/annurev-genom.9.081307.164359
# Called download_file with href: https://doi.org/10.1038/nature03959 and filename: Margulies_2005_Nature.pdf
# Taken 65.6 seconds to complete.
# ...

# %%
m.close()
